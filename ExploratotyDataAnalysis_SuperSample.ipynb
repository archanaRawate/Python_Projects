# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
eda = pd.read_excel("/content/SuperStore Sales DataSet.xlsx") #loading Excel file

# %%
eda
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                 4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1                 4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 2                 4920  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 3                 3074  CA-2019-125206 2019-01-03 2019-01-05     First Class
# 4                 8604  US-2019-116365 2019-01-03 2019-01-08  Standard Class
# ...                ...             ...        ...        ...             ...
# 5896               907  CA-2020-143259 2020-12-30 2021-01-03  Standard Class
# 5897              1297  CA-2020-115427 2020-12-30 2021-01-03  Standard Class
# 5898              5092  CA-2020-156720 2020-12-30 2021-01-03  Standard Class
# 5899               909  CA-2020-143259 2020-12-30 2021-01-03  Standard Class
# 5900              5093  CA-2020-151450 2020-12-31 2021-01-04  Standard Class
#
#      Customer ID      Customer Name    Segment        Country           City  \
# 0       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 1       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 2       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 3       LR-16915       Lena Radford   Consumer  United States    Los Angeles
# 4       CA-12310  Christine Abelman  Corporate  United States    San Antonio
# ...          ...                ...        ...            ...            ...
# 5896    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 5897    EB-13975         Erica Bern  Corporate  United States      Fairfield
# 5898    JM-15580      Jill Matthias   Consumer  United States       Loveland
# 5899    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 5900    JM-15580      Jill Matthias   Consumer  United States       Loveland
#
#       ...         Category Sub-Category  \
# 0     ...        Furniture    Bookcases
# 1     ...        Furniture    Bookcases
# 2     ...       Technology       Phones
# 3     ...  Office Supplies      Storage
# 4     ...       Technology  Accessories
# ...   ...              ...          ...
# 5896  ...        Furniture    Bookcases
# 5897  ...  Office Supplies      Binders
# 5898  ...  Office Supplies    Fasteners
# 5899  ...  Office Supplies      Binders
# 5900  ...  Office Supplies    Fasteners
#
#                                            Product Name     Sales Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...    73.940        1
# 1     Bush Westfield Collection Bookcases, Medium Ch...   173.940        3
# 2                                           GE 30522EE2   231.980        2
# 3     Recycled Steel Personal File for Hanging File ...   114.460        2
# 4                   Imation Clip USB flash drive - 8 GB    30.080        2
# ...                                                 ...       ...      ...
# 5896  Bush Westfield Collection Bookcases, Fully Ass...   213.136        4
# 5897    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904        2
# 5898                                Bagged Rubber Bands   388.024        3
# 5899               Wilson Jones Legal Size Ring Binders   462.776        3
# 5900                                Bagged Rubber Bands  2975.510        3
#
#        Profit  Returns  Payment Mode  ind1  ind2
# 0     28.2668      NaN        Online   NaN   NaN
# 1     38.2668      NaN        Online   NaN   NaN
# 2     67.2742      NaN         Cards   NaN   NaN
# 3     28.6150      NaN        Online   NaN   NaN
# 4     -5.2640      NaN        Online   NaN   NaN
# ...       ...      ...           ...   ...   ...
# 5896  12.1176      NaN           COD   NaN   NaN
# 5897   4.5188      1.0        Online   NaN   NaN
# 5898  -0.6048      NaN        Online   NaN   NaN
# 5899  19.7910      NaN           COD   NaN   NaN
# 5900  -0.6048      NaN           COD   NaN   NaN
#
# [5901 rows x 23 columns]

# %%
eda1 = pd.read_csv("/content/SuperStore_Sales_Dataset.csv", encoding="latin1") #loading csv file

# %%
eda1.head(5)
# Out:
#    ï»¿Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
#
#         Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0  Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1  Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2  Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3     First Class    LR-16915       Lena Radford   Consumer  United States
# 4  Standard Class    CA-12310  Christine Abelman  Corporate  United States
#
#            City  ...         Category Sub-Category  \
# 0  Gaithersburg  ...        Furniture    Bookcases
# 1  Gaithersburg  ...        Furniture    Bookcases
# 2  Gaithersburg  ...       Technology       Phones
# 3   Los Angeles  ...  Office Supplies      Storage
# 4   San Antonio  ...       Technology  Accessories
#
#                                         Product Name   Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94        1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94        3
# 2                                        GE 30522EE2  231.98        2
# 3  Recycled Steel Personal File for Hanging File ...  114.46        2
# 4             ImationÂ Clip USBÂ flash driveÂ - 8 GB   30.08        2
#
#     Profit  Returns  Payment Mode  ind1  ind2
# 0  28.2668      NaN        Online   NaN   NaN
# 1  38.2668      NaN        Online   NaN   NaN
# 2  67.2742      NaN         Cards   NaN   NaN
# 3  28.6150      NaN        Online   NaN   NaN
# 4  -5.2640      NaN        Online   NaN   NaN
#
# [5 rows x 23 columns]

# %%
eda1.sample(4)
# Out:
#       ï»¿Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 1407                 5384  CA-2019-149195  05-09-2019  07-09-2019
# 906                  8261  CA-2019-118101  26-06-2019  26-06-2019
# 1359                 5354  US-2019-101616  03-09-2019  06-09-2019
# 5685                 2948  CA-2020-169859  14-12-2020  18-12-2020
#
#            Ship Mode Customer ID   Customer Name      Segment        Country  \
# 1407    Second Class    DM-13525      Don Miller    Corporate  United States
# 906         Same Day    SN-20560    Skye Norling  Home Office  United States
# 1359     First Class    CY-12745    Craig Yedwab    Corporate  United States
# 5685  Standard Class    MP-18175  Mike Pelletier  Home Office  United States
#
#            City  ...         Category Sub-Category  \
# 1407    Houston  ...  Office Supplies        Paper
# 906   Roseville  ...  Office Supplies      Binders
# 1359     Monroe  ...  Office Supplies      Binders
# 5685  San Diego  ...  Office Supplies      Binders
#
#                                            Product Name    Sales Quantity  \
# 1407                                         Xerox 1930   10.368        2
# 906                 Insertable Tab Post Binder Dividers    8.020        1
# 1359                           Heavy-Duty E-Z-D Binders   87.280        8
# 5685  Wilson Jones Clip & Carry Folder Binder Tool f...  391.960       14
#
#        Profit  Returns  Payment Mode  ind1  ind2
# 1407   3.7584      NaN           COD   NaN   NaN
# 906    3.7694      NaN        Online   NaN   NaN
# 1359  41.0216      NaN        Online   NaN   NaN
# 5685  22.7360      1.0           COD   NaN   NaN
#
# [4 rows x 23 columns]

# %%
eda1.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID             5901 non-null   object
#  2   Order Date           5901 non-null   object
#  3   Ship Date            5901 non-null   object
#  4   Ship Mode            5901 non-null   object
#  5   Customer ID          5901 non-null   object
#  6   Customer Name        5901 non-null   object
#  7   Segment              5901 non-null   object
#  8   Country              5901 non-null   object
#  9   City                 5901 non-null   object
#  10  State                5901 non-null   object
#  11  Region               5901 non-null   object
#  12  Product ID           5901 non-null   object
#  13  Category             5901 non-null   object
#  14  Sub-Category         5901 non-null   object
#  15  Product Name         5901 non-null   object
#  16  Sales                5901 non-null   float64
#  17  Quantity             5901 non-null   int64
#  18  Profit               5901 non-null   float64
#  19  Returns              287 non-null    float64
#  20  Payment Mode         5901 non-null   object
#  21  ind1                 0 non-null      float64
#  22  ind2                 0 non-null      float64
# dtypes: float64(5), int64(2), object(16)
# memory usage: 1.0+ MB

# %%
eda1.describe()
# Out:
#        ï»¿Row ID+O6G3A1:R6        Sales     Quantity       Profit  Returns  \
# count          5901.000000  5901.000000  5901.000000  5901.000000    287.0
# mean           5022.422471   265.345589     3.781901    29.700408      1.0
# std            2877.977184   474.260645     2.212917   259.589138      0.0
# min               1.000000     0.836000     1.000000 -6599.978000      1.0
# 25%            2486.000000    71.976000     2.000000     1.795500      1.0
# 50%            5091.000000   128.648000     3.000000     8.502500      1.0
# 75%            7456.000000   265.170000     5.000000    28.615000      1.0
# max            9994.000000  9099.930000    14.000000  8399.976000      1.0
#
#        ind1  ind2
# count   0.0   0.0
# mean    NaN   NaN
# std     NaN   NaN
# min     NaN   NaN
# 25%     NaN   NaN
# 50%     NaN   NaN
# 75%     NaN   NaN
# max     NaN   NaN

# %%
eda1.shape
# Out:
# (5901, 23)

# %%
#missing value

eda1.isnull().sum()
# Out:
# ï»¿Row ID+O6G3A1:R6       0
# Order ID                  0
# Order Date                0
# Ship Date                 0
# Ship Mode                 0
# Customer ID               0
# Customer Name             0
# Segment                   0
# Country                   0
# City                      0
# State                     0
# Region                    0
# Product ID                0
# Category                  0
# Sub-Category              0
# Product Name              0
# Sales                     0
# Quantity                  0
# Profit                    0
# Returns                5614
# Payment Mode              0
# ind1                   5901
# ind2                   5901
# dtype: int64

# %%
eda1["Returns"].fillna(eda1["Returns"].mean(),inplace =True) #if there is NA value then we can fill that with this code

# %%
#dropping columns

eda1.drop(columns=["ind1","ind2"])
# Out:
#       ï»¿Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                    4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                    4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                    4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                    3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                    8604  US-2019-116365  03-01-2019  08-01-2019
# ...                   ...             ...         ...         ...
# 5896                  907  CA-2020-143259  30-12-2020  03-01-2021
# 5897                 1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898                 5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899                  909  CA-2020-143259  30-12-2020  03-01-2021
# 5900                 5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3        First Class    LR-16915       Lena Radford   Consumer  United States
# 4     Standard Class    CA-12310  Christine Abelman  Corporate  United States
# ...              ...         ...                ...        ...            ...
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                City  ...   Region       Product ID         Category  \
# 0      Gaithersburg  ...     East  FUR-BO-10004709        Furniture
# 1      Gaithersburg  ...     East  FUR-BO-10004709        Furniture
# 2      Gaithersburg  ...     East  TEC-PH-10000455       Technology
# 3       Los Angeles  ...     West  OFF-ST-10003692  Office Supplies
# 4       San Antonio  ...  Central  TEC-AC-10002217       Technology
# ...             ...  ...      ...              ...              ...
# 5896  New York City  ...     East  FUR-BO-10003441        Furniture
# 5897      Fairfield  ...     West  OFF-BI-10002103  Office Supplies
# 5898       Loveland  ...     West  OFF-FA-10003472  Office Supplies
# 5899  New York City  ...     East  OFF-BI-10003684  Office Supplies
# 5900       Loveland  ...     West  OFF-FA-10003472  Office Supplies
#
#      Sub-Category                                       Product Name  \
# 0       Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 1       Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 2          Phones                                        GE 30522EE2
# 3         Storage  Recycled Steel Personal File for Hanging File ...
# 4     Accessories             ImationÂ Clip USBÂ flash driveÂ - 8 GB
# ...           ...                                                ...
# 5896    Bookcases  Bush Westfield Collection Bookcases, Fully Ass...
# 5897      Binders    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# 5898    Fasteners                                Bagged Rubber Bands
# 5899      Binders               Wilson Jones Legal Size Ring Binders
# 5900    Fasteners                                Bagged Rubber Bands
#
#          Sales  Quantity   Profit  Returns  Payment Mode
# 0       73.940         1  28.2668      1.0        Online
# 1      173.940         3  38.2668      1.0        Online
# 2      231.980         2  67.2742      1.0         Cards
# 3      114.460         2  28.6150      1.0        Online
# 4       30.080         2  -5.2640      1.0        Online
# ...        ...       ...      ...      ...           ...
# 5896   213.136         4  12.1176      1.0           COD
# 5897   295.904         2   4.5188      1.0        Online
# 5898   388.024         3  -0.6048      1.0        Online
# 5899   462.776         3  19.7910      1.0           COD
# 5900  2975.510         3  -0.6048      1.0           COD
#
# [5901 rows x 21 columns]

# %%
eda1.head(2)
# Out:
#    ï»¿Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
#
#         Ship Mode Customer ID  Customer Name    Segment        Country  \
# 0  Standard Class    BM-11575  Brendan Murry  Corporate  United States
# 1  Standard Class    BM-11575  Brendan Murry  Corporate  United States
#
#            City  ...   Category Sub-Category  \
# 0  Gaithersburg  ...  Furniture    Bookcases
# 1  Gaithersburg  ...  Furniture    Bookcases
#
#                                         Product Name   Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94        1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94        3
#
#     Profit  Returns  Payment Mode  ind1  ind2
# 0  28.2668      1.0        Online   NaN   NaN
# 1  38.2668      1.0        Online   NaN   NaN
#
# [2 rows x 23 columns]

# %%
#univerient analysis

eda1["Ship Mode"].value_counts() #counting the numbers of shipping mode
# Out:
# Ship Mode
# Standard Class    3451
# Second Class      1147
# First Class        959
# Same Day           344
# Name: count, dtype: int64

# %%
eda1["Region"].value_counts()
# Out:
# Region
# West       1901
# East       1688
# Central    1381
# South       931
# Name: count, dtype: int64

# %%
eda1["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Phones', 'Storage', 'Accessories', 'Tables',
#        'Binders', 'Copiers', 'Art', 'Furnishings', 'Paper', 'Envelopes',
#        'Chairs', 'Fasteners', 'Appliances', 'Labels', 'Machines',
#        'Supplies'], dtype=object)

# %%
eda1["City"].unique()
# Out:
# array(['Gaithersburg', 'Los Angeles', 'San Antonio', 'Broken Arrow',
#        'Charlotte', 'Philadelphia', 'Jacksonville', 'Oakland', 'Amarillo',
#        'Franklin', 'Raleigh', 'Fresno', 'Toledo', 'Seattle', 'Longview',
#        'Springfield', 'Columbus', 'Concord', 'Westfield', 'Fairfield',
#        'New York City', 'San Diego', 'Morristown', 'Fayetteville',
#        'Cleveland', 'Burlington', 'Gulfport', 'Plainfield',
#        'San Francisco', 'Chicago', 'Rockford', 'Dallas', 'Atlantic City',
#        'Atlanta', 'Arlington', 'Houston', 'Richmond', 'Sierra Vista',
#        'Rockville', 'Smyrna', 'Chattanooga', 'Lancaster', 'Tulsa',
#        'Clinton', 'Jackson', 'Belleville', 'Henderson', 'Long Beach',
#        'Nashville', 'Oceanside', 'Tampa', 'Milwaukee', 'Newark',
#        'La Crosse', 'Yonkers', 'Denver', 'Odessa', 'Bloomington',
#        'Round Rock', 'Miami', 'Mishawaka', 'Dover', 'Fort Worth',
#        'Glendale', 'Milford', 'Andover', 'Eagan', 'Vineland', 'Monroe',
#        'Scottsdale', 'Waynesboro', 'Riverside', 'Harlingen',
#        'Redwood City', 'Green Bay', 'Bryan', 'Malden', 'Columbia',
#        'Memphis', 'Littleton', 'Salem', 'Evanston', 'Saint Peters',
#        'North Las Vegas', 'Gresham', 'Norman', 'Pocatello', 'Norwich',
#        'Auburn', 'Troy', 'Lakewood', 'Hot Springs', 'Detroit',
#        'Bakersfield', 'Wilson', 'Alexandria', 'Baltimore', 'Gastonia',
#        'Grapevine', 'Omaha', 'Elmhurst', 'Chesapeake', 'Phoenix',
#        'Jefferson City', 'Aurora', 'Rome', 'Hesperia', 'San Clemente',
#        'Colorado Springs', 'Saint Charles', 'Little Rock', 'Greensboro',
#        'Irving', 'Louisville', 'Murfreesboro', 'Encinitas', 'Tallahassee',
#        'Lorain', 'Austin', 'Virginia Beach', 'Mission Viejo',
#        'Cincinnati', 'Yuma', 'Fort Lauderdale', 'Middletown', 'Apopka',
#        'Waterbury', 'Lafayette', 'Vallejo', 'Asheville',
#        'Port Saint Lucie', 'Sparks', 'Warwick', 'Passaic', 'Athens',
#        'Florence', 'Newport News', 'Washington', 'Santa Ana',
#        'Delray Beach', 'Park Ridge', 'Montgomery', 'Parker', 'Wilmington',
#        'Hamilton', 'Superior', 'Decatur', 'Santa Clara', 'Lowell',
#        'Santa Barbara', 'Minneapolis', 'Pasadena', 'Wichita', 'Anaheim',
#        'Boca Raton', 'Longmont', 'Rochester', 'Frankfort', 'Salinas',
#        'Carrollton', 'Oklahoma City', 'Buffalo', 'York', 'Providence',
#        'Plano', 'Roseville', 'Highland Park', 'Paterson', 'Sandy Springs',
#        'Lehi', 'Huntsville', 'Hialeah', 'San Jose', 'Orem', 'Broomfield',
#        'Mesa', 'Tucson', 'Provo', 'Portland', 'Grand Prairie',
#        'Perth Amboy', 'Bowling Green', 'Hattiesburg', 'Allentown',
#        'Westland', 'Mcallen', 'Costa Mesa', 'Holland', 'Bethlehem',
#        'Pensacola', 'Suffolk', 'Peoria', 'Sacramento', 'Edmonds',
#        'Hendersonville', 'Des Moines', 'Lakeland', 'West Allis', 'Kenner',
#        'Akron', 'Davis', 'Edinburg', 'Greenville', 'Fort Collins',
#        'Pharr', 'Sheboygan', 'Quincy', 'Hollywood', 'Englewood', 'Waco',
#        'Huntington Beach', 'Madison', 'Waukesha', 'Knoxville',
#        'Georgetown', 'Woodbury', 'Jonesboro', 'Cedar Rapids', 'Olathe',
#        'Johnson City', 'Redondo Beach', 'Saint Paul', 'Thomasville',
#        'Wheeling', 'Visalia', 'Stockton', 'Bristol', 'Arvada', 'Utica',
#        'Twin Falls', 'Laguna Niguel', 'Bangor', 'Marlborough', 'Redmond',
#        'New Rochelle', 'Woodland', 'Orange', 'Grand Rapids',
#        'Pembroke Pines', 'Lawrence', 'Parma', 'Tigard', 'Covington',
#        'Iowa City', 'Redlands', 'Mobile', 'La Porte', 'Lake Forest',
#        'The Colony', 'Coral Gables', 'Pueblo', 'Spokane', 'Marysville',
#        'Laredo', 'Appleton', 'Salt Lake City', 'Tempe', 'Trenton',
#        'El Cajon', 'Manchester', 'Lebanon', 'Hampton', 'Boynton Beach',
#        'Bridgeton', 'Lansing', 'Sterling Heights', 'San Luis Obispo',
#        'Conroe', 'Urbandale', 'Chula Vista', 'Eugene', 'Cheyenne',
#        'Warner Robins', 'Noblesville', 'Arlington Heights', 'Vancouver',
#        'Carlsbad', 'Kent', 'Taylor', 'Niagara Falls', 'Indianapolis',
#        'Edmond', 'Orlando', 'Montebello', 'Medford', 'Bellevue',
#        'El Paso', 'Shelton', 'Lincoln Park', 'Overland Park',
#        'East Orange', 'Palm Coast', 'Marietta', 'Hickory', 'Oxnard',
#        'San Angelo', 'Marion', 'Morgan Hill', 'Murray', 'Hempstead',
#        'Antioch', 'Richardson', 'Eau Claire', 'Fremont', 'Greenwood',
#        'Watertown', 'Homestead', 'Torrance', 'Cuyahoga Falls',
#        'Apple Valley', 'Goldsboro', 'Tamarac', 'Reading', 'Moreno Valley',
#        'Nashua', 'Woodstock', 'Port Arthur', 'West Palm Beach',
#        'Deer Park', 'Reno', 'Rancho Cucamonga', 'Tuscaloosa',
#        'Ormond Beach', 'Keller', 'Great Falls', 'Hoover', 'Roswell',
#        'Gilbert', 'Muskogee', 'Dearborn Heights', 'Southaven', 'Chester',
#        'Cambridge', 'Rogers', 'Albuquerque', 'Manteca', 'Tyler',
#        'Pompano Beach', 'Beaumont', 'Dearborn', 'Meriden', 'Des Plaines',
#        'Oak Park', 'New Brunswick', 'Lubbock', 'Clarksville', 'Greeley',
#        'Chandler', 'Kissimmee', 'Dublin', 'Sanford', 'Danville',
#        'Coral Springs', 'Texarkana', 'Westminster', 'Mansfield',
#        'Everett', 'Mount Vernon', 'Fargo', 'Las Vegas', 'Harrisonburg',
#        'Laurel', 'Bellingham', 'Missouri City', 'Frisco', 'Pearland',
#        'Skokie', 'Rochester Hills', 'Thousand Oaks', 'Saint Petersburg',
#        'Maple Grove', 'Chapel Hill', 'Olympia', 'Commerce City',
#        'Corpus Christi', 'Cranston', 'Pomona', 'Bolingbrook', 'Mesquite',
#        'Citrus Heights', 'Farmington', 'San Mateo', 'Pico Rivera',
#        'Waterloo', 'Sioux Falls', 'Elkhart', 'Kenosha', 'Loveland',
#        'Cedar Hill', 'Moorhead', 'Bedford', 'Lake Charles', 'Brentwood',
#        'New Bedford', 'Lakeville', 'Inglewood', 'La Mesa', 'Coppell',
#        'Garland', 'Draper', 'Modesto', 'Independence', 'Naperville',
#        'Woonsocket', 'Boise', 'Clovis', 'Grand Island', 'Melbourne',
#        'Pine Bluff', 'Saint Cloud', 'Helena', 'Miramar', 'Brownsville',
#        'Mentor', 'Lodi', 'Chico', 'Meridian', 'League City', 'Freeport',
#        'Camarillo', 'Durham', 'Deltona', 'Lawton', 'Saint Louis',
#        'Las Cruces', 'Springdale', 'Coachella', 'Sunnyvale', 'Pasco',
#        'Aberdeen', 'Jupiter', 'Grove City', 'Elyria', 'Escondido',
#        'Hillsboro', 'Hagerstown', 'Saginaw', 'College Station', 'Ontario',
#        'Renton', 'Canton', 'Summerville', 'Garden City', 'Gladstone',
#        'Charlottesville', 'Thornton', 'Whittier', 'North Charleston',
#        'Palatine', 'Abilene', 'Port Orange', 'Danbury'], dtype=object)

# %%
eda1["Payment Mode"] == eda1["Payment Mode"].replace("COD","Cod")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5896    False
# 5897     True
# 5898     True
# 5899    False
# 5900    False
# Name: Payment Mode, Length: 5901, dtype: bool

# %%
eda1
# Out:
#       ï»¿Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                    4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                    4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                    4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                    3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                    8604  US-2019-116365  03-01-2019  08-01-2019
# ...                   ...             ...         ...         ...
# 5896                  907  CA-2020-143259  30-12-2020  03-01-2021
# 5897                 1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898                 5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899                  909  CA-2020-143259  30-12-2020  03-01-2021
# 5900                 5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3        First Class    LR-16915       Lena Radford   Consumer  United States
# 4     Standard Class    CA-12310  Christine Abelman  Corporate  United States
# ...              ...         ...                ...        ...            ...
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                City  ...         Category Sub-Category  \
# 0      Gaithersburg  ...        Furniture    Bookcases
# 1      Gaithersburg  ...        Furniture    Bookcases
# 2      Gaithersburg  ...       Technology       Phones
# 3       Los Angeles  ...  Office Supplies      Storage
# 4       San Antonio  ...       Technology  Accessories
# ...             ...  ...              ...          ...
# 5896  New York City  ...        Furniture    Bookcases
# 5897      Fairfield  ...  Office Supplies      Binders
# 5898       Loveland  ...  Office Supplies    Fasteners
# 5899  New York City  ...  Office Supplies      Binders
# 5900       Loveland  ...  Office Supplies    Fasteners
#
#                                            Product Name     Sales Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...    73.940        1
# 1     Bush Westfield Collection Bookcases, Medium Ch...   173.940        3
# 2                                           GE 30522EE2   231.980        2
# 3     Recycled Steel Personal File for Hanging File ...   114.460        2
# 4                ImationÂ Clip USBÂ flash driveÂ - 8 GB    30.080        2
# ...                                                 ...       ...      ...
# 5896  Bush Westfield Collection Bookcases, Fully Ass...   213.136        4
# 5897    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904        2
# 5898                                Bagged Rubber Bands   388.024        3
# 5899               Wilson Jones Legal Size Ring Binders   462.776        3
# 5900                                Bagged Rubber Bands  2975.510        3
#
#        Profit  Returns  Payment Mode  ind1  ind2
# 0     28.2668      1.0        Online   NaN   NaN
# 1     38.2668      1.0        Online   NaN   NaN
# 2     67.2742      1.0         Cards   NaN   NaN
# 3     28.6150      1.0        Online   NaN   NaN
# 4     -5.2640      1.0        Online   NaN   NaN
# ...       ...      ...           ...   ...   ...
# 5896  12.1176      1.0           COD   NaN   NaN
# 5897   4.5188      1.0        Online   NaN   NaN
# 5898  -0.6048      1.0        Online   NaN   NaN
# 5899  19.7910      1.0           COD   NaN   NaN
# 5900  -0.6048      1.0           COD   NaN   NaN
#
# [5901 rows x 23 columns]

# %%
plt.figsize=(6,3)#defining size
sns.countplot(x = "Ship Mode", data =eda1)
plt.title = ("ount of Shiping Mode")
plt.show()

# %%
# prompt: pie chart

import matplotlib.pyplot as plt
plt.figure(figsize=(6, 3))
eda1['Ship Mode'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.title=('Pie Chart of Shipping Modes')
plt.savefig("Pie Chart of Shipping Modes")
plt.show()

# %%
plt.figure(figsize=(6,3))
eda1["Payment Mode"].value_counts().plot(kind="pie",autopct='%1.1f%%',shadow=True)
plt.title=("Most Use Payment Mode")
plt.savefig("Most Use Payment Mode")
plt.legend(loc=2)

plt.show()

# %%
plt.figure(figsize=(6,3))

eda1["Payment Mode"].value_counts().plot(kind="pie",autopct='%1.1f%%',shadow=True)
plt.title=("Most Use Payment Mode")
plt.legend(loc = 2)
plt.show()

# %%
#Segment

eda1["Segment"].value_counts()
# Out:
# Segment
# Consumer       2997
# Corporate      1774
# Home Office    1130
# Name: count, dtype: int64

# %%
x= eda1["Segment"].value_counts().index

# %%
y= eda1["Segment"].value_counts().values

# %%
plt.scatter(x,y)
plt.xlabel("Units")
plt.ylabel("Segmet")
plt.title = ("Scatter plot for Segment Of Orders ")
plt.show()

# %%
plt.scatter(x,y)

plt.plot(x,y, c="green", linewidth=2)
plt.xlabel("X ")
plt.ylabel("Y ")
plt.title=("Scatter Plot with Lines")

# Show the plot
plt.show()

# %%
plt.boxplot(eda1["Segment"].value_counts().values)
plt.title = ("Sales By Region")
eda1(["Region"].value_counts().values),plot(kind="boxplot",autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(5,3))
eda1["Sales"].plot(kind="density", color="blue", title="Density Plot of Region")
plt.show()

# %%
eda1.head(3)
# Out:
#    ï»¿Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
#
#         Ship Mode Customer ID  Customer Name    Segment        Country  \
# 0  Standard Class    BM-11575  Brendan Murry  Corporate  United States
# 1  Standard Class    BM-11575  Brendan Murry  Corporate  United States
# 2  Standard Class    BM-11575  Brendan Murry  Corporate  United States
#
#            City  ...    Category Sub-Category  \
# 0  Gaithersburg  ...   Furniture    Bookcases
# 1  Gaithersburg  ...   Furniture    Bookcases
# 2  Gaithersburg  ...  Technology       Phones
#
#                                         Product Name   Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94        1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94        3
# 2                                        GE 30522EE2  231.98        2
#
#     Profit  Returns  Payment Mode  ind1  ind2
# 0  28.2668      1.0        Online   NaN   NaN
# 1  38.2668      1.0        Online   NaN   NaN
# 2  67.2742      1.0         Cards   NaN   NaN
#
# [3 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,3))
sns.countplot(x="Segment", data = eda1, hue="Category")
plt.title=("Customer Segment")
plt.show()

# %%
plt.figure(figsize=(20,3))
sns.countplot(x="Sub-Category",data=eda1)
plt.title=("Top performer in Sub category")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Category", data=eda1, hue="Sub-Category")
plt.title=("Top Performer")
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(x="Category", data=eda1[eda1["Category"]=="Office Supplies"], hue = "Sub-Category")
plt.legend(loc=5)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Category" , data=eda1[eda1["Category"]=="Furniture"],hue= "Sub-Category")
plt.show()

# %%
plt.figsize=(6,3)
sns.countplot(x="Category", data=eda1[eda1["Category"]=="Technology"], hue = "Sub-Category")
plt.show()

# %%
eda1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID             5901 non-null   object
#  2   Order Date           5901 non-null   object
#  3   Ship Date            5901 non-null   object
#  4   Ship Mode            5901 non-null   object
#  5   Customer ID          5901 non-null   object
#  6   Customer Name        5901 non-null   object
#  7   Segment              5901 non-null   object
#  8   Country              5901 non-null   object
#  9   City                 5901 non-null   object
#  10  State                5901 non-null   object
#  11  Region               5901 non-null   object
#  12  Product ID           5901 non-null   object
#  13  Category             5901 non-null   object
#  14  Sub-Category         5901 non-null   object
#  15  Product Name         5901 non-null   object
#  16  Sales                5901 non-null   float64
#  17  Quantity             5901 non-null   int64
#  18  Profit               5901 non-null   float64
#  19  Returns              5901 non-null   float64
#  20  Payment Mode         5901 non-null   object
#  21  ind1                 0 non-null      float64
#  22  ind2                 0 non-null      float64
# dtypes: float64(5), int64(2), object(16)
# memory usage: 1.0+ MB

# %%
#converting a string to a datetime
string_data= "2023-04-10"
datatime_object = pd.to_datetime(string_data)
print(datatime_object)
# Out:
# 2023-04-10 00:00:00

# %%
from datetime import datetime

# %%
# Convert the "date_column" to datetime type
eda1["Ship Date1"] = pd.to_datetime(eda1["Ship Date"], format = "%d/%m/%Y")
print(eda1)
# Out:
#       ï»¿Row ID+O6G3A1:R6        Order ID  Order Date  Ship Date  \
# 0                    4918  CA-2019-160304  01-01-2019 2019-07-01
# 1                    4919  CA-2019-160304  02-01-2019 2019-07-01
# 2                    4920  CA-2019-160304  02-01-2019 2019-07-01
# 3                    3074  CA-2019-125206  03-01-2019 2019-05-01
# 4                    8604  US-2019-116365  03-01-2019 2019-08-01
# ...                   ...             ...         ...        ...
# 5896                  907  CA-2020-143259  30-12-2020 2021-03-01
# 5897                 1297  CA-2020-115427  30-12-2020 2021-03-01
# 5898                 5092  CA-2020-156720  30-12-2020 2021-03-01
# 5899                  909  CA-2020-143259  30-12-2020 2021-03-01
# 5900                 5093  CA-2020-151450  31-12-2020 2021-04-01
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3        First Class    LR-16915       Lena Radford   Consumer  United States
# 4     Standard Class    CA-12310  Christine Abelman  Corporate  United States
# ...              ...         ...                ...        ...            ...
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                City  ... Sub-Category  \
# 0      Gaithersburg  ...    Bookcases
# 1      Gaithersburg  ...    Bookcases
# 2      Gaithersburg  ...       Phones
# 3       Los Angeles  ...      Storage
# 4       San Antonio  ...  Accessories
# ...             ...  ...          ...
# 5896  New York City  ...    Bookcases
# 5897      Fairfield  ...      Binders
# 5898       Loveland  ...    Fasteners
# 5899  New York City  ...      Binders
# 5900       Loveland  ...    Fasteners
#
#                                            Product Name     Sales Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...    73.940        1
# 1     Bush Westfield Collection Bookcases, Medium Ch...   173.940        3
# 2                                           GE 30522EE2   231.980        2
# 3     Recycled Steel Personal File for Hanging File ...   114.460        2
# 4                ImationÂ Clip USBÂ flash driveÂ - 8 GB    30.080        2
# ...                                                 ...       ...      ...
# 5896  Bush Westfield Collection Bookcases, Fully Ass...   213.136        4
# 5897    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904        2
# 5898                                Bagged Rubber Bands   388.024        3
# 5899               Wilson Jones Legal Size Ring Binders   462.776        3
# 5900                                Bagged Rubber Bands  2975.510        3
#
#        Profit Returns  Payment Mode  ind1  ind2  Ship Date1
# 0     28.2668     1.0        Online   NaN   NaN  2019-07-01
# 1     38.2668     1.0        Online   NaN   NaN  2019-07-01
# 2     67.2742     1.0         Cards   NaN   NaN  2019-07-01
# 3     28.6150     1.0        Online   NaN   NaN  2019-05-01
# 4     -5.2640     1.0        Online   NaN   NaN  2019-08-01
# ...       ...     ...           ...   ...   ...         ...
# 5896  12.1176     1.0           COD   NaN   NaN  2021-03-01
# 5897   4.5188     1.0        Online   NaN   NaN  2021-03-01
# 5898  -0.6048     1.0        Online   NaN   NaN  2021-03-01
# 5899  19.7910     1.0           COD   NaN   NaN  2021-03-01
# 5900  -0.6048     1.0           COD   NaN   NaN  2021-04-01
#
# [5901 rows x 24 columns]

# %%
eda1["Ship Date"] = pd.to_datetime(eda1["Ship Date"], format="mixed")

# %%
eda1["Order_Date"] = pd.to_datetime(eda1["Order Date"], format='mixed')

# %%
eda1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID             5901 non-null   object
#  2   Order Date           5901 non-null   object
#  3   Ship Date            5901 non-null   datetime64[ns]
#  4   Ship Mode            5901 non-null   object
#  5   Customer ID          5901 non-null   object
#  6   Customer Name        5901 non-null   object
#  7   Segment              5901 non-null   object
#  8   Country              5901 non-null   object
#  9   City                 5901 non-null   object
#  10  State                5901 non-null   object
#  11  Region               5901 non-null   object
#  12  Product ID           5901 non-null   object
#  13  Category             5901 non-null   object
#  14  Sub-Category         5901 non-null   object
#  15  Product Name         5901 non-null   object
#  16  Sales                5901 non-null   float64
#  17  Quantity             5901 non-null   int64
#  18  Profit               5901 non-null   float64
#  19  Returns              5901 non-null   float64
#  20  Payment Mode         5901 non-null   object
#  21  ind1                 0 non-null      float64
#  22  ind2                 0 non-null      float64
#  23  Ship Date1           5901 non-null   datetime64[ns]
#  24  Order_Date           5901 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(5), int64(2), object(15)
# memory usage: 1.1+ MB

# %%
eda1["Order Year"]= eda1["Order_Date"].dt.year

# %%
eda1["Order Year"].value_counts()
# Out:
# Order Year
# 2020    3313
# 2019    2588
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.countplot(x="Order Year", data=eda1, palette=["green","blue"])
plt.title = ("Yearly Order Received")
plt.show()
# Out:
# <ipython-input-73-78ba9f39b259>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Order Year", data=eda1, palette=["green","blue"])

# %%
#profit

sns.barplot(x="Category", y= "Profit", data=eda1,estimator="sum")
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.pointplot(x="Sub-Category", y= "Profit", data=eda1,estimator="mean")
plt.xticks(rotation=90)

plt.show()

# %%
eda1["State"].value_counts()
# Out:
# State
# California              1189
# New York                 672
# Texas                    565
# Washington               337
# Pennsylvania             335
# Illinois                 293
# Ohio                     293
# Florida                  212
# North Carolina           159
# Michigan                 138
# Tennessee                120
# Georgia                  115
# Colorado                 114
# Arizona                  113
# Virginia                 104
# Indiana                   96
# New Jersey                92
# Wisconsin                 77
# Kentucky                  73
# Oregon                    65
# Massachusetts             63
# Maryland                  63
# Connecticut               56
# Oklahoma                  49
# Minnesota                 46
# Delaware                  43
# Missouri                  40
# Arkansas                  39
# Mississippi               36
# Rhode Island              36
# Alabama                   35
# New Mexico                26
# Nebraska                  25
# Iowa                      24
# Utah                      23
# Louisiana                 19
# South Carolina            19
# Nevada                    16
# Kansas                    13
# New Hampshire             13
# Idaho                     12
# Vermont                    9
# South Dakota               8
# District of Columbia       7
# North Dakota               7
# Montana                    5
# West Virginia              4
# Maine                      2
# Wyoming                    1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))

State_counts = eda1["State"].value_counts().head(3)
State_counts.plot(kind="line")

plt.xlabel("State")
plt.ylabel("Number Of Orders")
plt.xticks(rotation=90)
plt.show()
print("Top 3 performer. Star is California state as it has maximum sales")
# Out:
# Top 3 performer. Star is California state as it has maximum sales

# %%
plt.figure(figsize=(6,3))

State_counts = eda1["State"].value_counts().head(7)
State_counts.plot(kind="line")

plt.xlabel("State")
plt.ylabel("Number Of Orders")
plt.xticks(rotation=90)
plt.show()
print("Top performers. Star is California state as it has maximum sales around 1200")
# Out:
# Top performers. Star is California state as it has maximum sales around 1200

# %%
eda1["State"].value_counts().head(5)
# Out:
# State
# California      1189
# New York         672
# Texas            565
# Washington       337
# Pennsylvania     335
# Name: count, dtype: int64

# %%
eda1["State"].value_counts()[:10]
# Out:
# State
# California        1189
# New York           672
# Texas              565
# Washington         337
# Pennsylvania       335
# Illinois           293
# Ohio               293
# Florida            212
# North Carolina     159
# Michigan           138
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.barplot(x = "Category", y="Profit",data=eda1, ci=95, n_boot=100)
plt.show()

#max profit earned by Technology Category
# Out:
# <ipython-input-99-b5ba3d6b92c7>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x = "Category", y="Profit",data=eda1, ci=95, n_boot=100)

# %%
eda1["Sales"] = pd.to_numeric(eda1["Sales"])

plt.figure(figsize=(6,3))
sns.boxenplot(x ="Category", y="Sales", data=eda1)
plt.title=("Top Saler category")

# %%
plt.figure(figsize=(6,3))
sns.barplot(x = "Sub-Category", y="Profit",data=eda1, ci=95, n_boot=100)
plt.xticks(rotation=90)

plt.show()

#For graph we conclude maximum profit earned by sub category copies  it means profit margin was good
# Out:
# <ipython-input-106-0d428276f09c>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x = "Sub-Category", y="Profit",data=eda1, ci=95, n_boot=100)

# %%
plt.figure(figsize=(6,3))
sns.barplot(x = "Sub-Category", y="Sales",data=eda1, ci=95, n_boot=100)
plt.xticks(rotation=90)

plt.show()
print("For graph we can conclude that the top sales received by sub category Copies and it follows by Machinery So maximum business coming from this sub categories")
print("Company need to improve srategies for sales in Art, Envelops, paper, labels as this subcategories sales is bottom line")
# Out:
# <ipython-input-108-7d4a2933684e>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x = "Sub-Category", y="Sales",data=eda1, ci=95, n_boot=100)
# For graph we can conclude that the top sales received by sub category Copies and it follows by Machinery So maximum business coming from this sub categories
# Company need to improve srategies for sales in Art, Envelops, paper, labels as this subcategories sales is bottom line

# %%
# Out:
# dtype('float64')
